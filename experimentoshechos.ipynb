# %%
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input
from keras.applications.vgg16 import VGG16
from keras import optimizers
from keras import applications
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.models import Sequential, Model 
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras import backend as k 
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
# %cd /content/drive/My Drive/deeplearning/2020.deeplearning/U3project/food
# Out:
# /content/drive/My Drive/deeplearning/2020.deeplearning/U3project/food

# %%
train_data_dir='prueba'

# %%
TEST_SPLIT = 0.25
epochs = 80
#batch_size = 16
batch_size=16
MICRO_DATA = True # very small subset (just 3 groups)
SAMPLE_TRAINING = False # make train set smaller for faster iteration
IMG_SIZE = (112, 112)
LEARNING_RATE = 3e-2
seed=1

# %%
train_datagen = ImageDataGenerator(rescale=1/255.,
    horizontal_flip=False,
    validation_split=0.2) # set validation split

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training', seed=seed) # set as training data

validation_generator = train_datagen.flow_from_directory(
    train_data_dir, # same directory as training data
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation', seed=seed) # set as validation data
# Out:
# Found 8037 images belonging to 10 classes.
# Found 2009 images belonging to 10 classes.

# %% [markdown]
# #8 clases:
# pancakes/     peking_duck/  pizza/      poutine/
#   panna_cotta/  pho/          pork_chop/  prime_rib/

# %%
model_final=tf.keras.models.load_model('vgg_finetuned_eightclasses.model')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
model_final=tf.keras.models.load_model('inception_finetuned_eightclasses.model')

# %% [markdown]
# inception 8 clases

# %%
#p_pr=model_final.predict(validation_generator)
loss, acc = model_final.evaluate_generator(validation_generator, 400)
print('Restored model, accuracy: {:5.2f}%'.format(100*acc))
# Out:
# Restored model, accuracy: 60.42%

# %% [markdown]
# para 10 clases mussels/  pancakes/     peking_duck/  pizza/      poutine/
# nachos/   panna_cotta/  pho/          pork_chop/  prime_rib/

# %%
model_final=tf.keras.models.load_model('vgg_finetuned_tenclasses.model')

# %%
train_datagen = ImageDataGenerator(rescale=1/255.,
    horizontal_flip=False,
    validation_split=0.2) # set validation split

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training', seed=seed) # set as training data

validation_generator = train_datagen.flow_from_directory(
    train_data_dir, # same directory as training data
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation', seed=seed) # set as validation data
# Out:
# Found 8037 images belonging to 10 classes.
# Found 2009 images belonging to 10 classes.

# %%
#p_pr=model_final.predict(validation_generator)
loss, acc = model_final.evaluate_generator(validation_generator, 400)
print('Restored model, accuracy: {:5.2f}%'.format(100*acc))
# Out:
# WARNING:tensorflow:From <ipython-input-12-a20a1287e49c>:1: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# Restored model, accuracy: 59.12%

# %% [markdown]
# Xception

# %%
model_final=tf.keras.models.load_model('Xception_finetuned_tenclasses.model')

# %%
loss, acc = model_final.evaluate_generator(validation_generator, 400)
print('Restored model, accuracy: {:5.2f}%'.format(100*acc))
# Out:
# Restored model, accuracy: 68.93%

# %%
model_final=tf.keras.models.load_model('Xception_finetuned_tenclasses')
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-26.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-26.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-26.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-26.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-27.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-27.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-27.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-27.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-27.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-27.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-27.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-27.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-27.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-45.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-45.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-45.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-45.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-46.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-46.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-46.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-46.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-28.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-28.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-28.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-28.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-28.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-28.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-29.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-29.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-29.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-29.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-29.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-29.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-29.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-29.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-29.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-49.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-49.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-49.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-49.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-30.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-30.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-30.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-30.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-30.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-30.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-31.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-31.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-31.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-31.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-31.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-31.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-31.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-31.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-31.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-52.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-52.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-52.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-52.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-32.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-32.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-32.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-32.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-32.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-32.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-33.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-33.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-33.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-33.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-33.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-33.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-33.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-33.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-33.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-55.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-55.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-55.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-55.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-56.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-56.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-56.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-56.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-34.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-34.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-34.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-34.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-34.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-34.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-35.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-35.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-35.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-35.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-35.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-35.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-35.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-35.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-35.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-59.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-59.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-59.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-59.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-36.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-36.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-36.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-36.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-36.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-36.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-37.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-37.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-37.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-37.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-37.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-37.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-37.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-37.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-37.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-62.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-62.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-62.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-62.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-38.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-38.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-38.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-38.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-38.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-38.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-39.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-39.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-39.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-39.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-39.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-39.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-39.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-39.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-39.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-65.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-65.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-65.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-65.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-66.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-66.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-66.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-66.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-40.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-40.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-40.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-40.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-40.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-40.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-41.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-41.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-41.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-41.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-41.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-41.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-41.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-41.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-41.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-69.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-69.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-69.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-69.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-42.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-42.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-42.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-42.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-42.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-42.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-43.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-43.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-43.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-43.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-43.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-43.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-43.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-43.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-43.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-72.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-72.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-72.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-72.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-44.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-44.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-44.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-44.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-44.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-44.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-45.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-45.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-45.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-45.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-45.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-45.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-45.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-45.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-45.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-75.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-75.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-75.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-75.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-76.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-76.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-76.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-76.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-46.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-46.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-46.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-46.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-46.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-46.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-47.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-47.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-47.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-47.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-47.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-47.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-47.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-47.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-47.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-79.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-79.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-79.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-79.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-48.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-48.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-48.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-48.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-48.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-48.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-49.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-49.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-49.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-49.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-49.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-49.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-49.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-49.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-49.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-82.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-82.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-82.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-82.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-50.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-50.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-50.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-50.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-50.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-50.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-51.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-51.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-51.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-51.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-51.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-51.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-51.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-51.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-51.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-85.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-85.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-85.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-85.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-86.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-86.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-86.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-86.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-52.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-52.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-52.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-52.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-52.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-52.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-53.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-53.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-53.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-53.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-53.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-53.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-53.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-53.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-53.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-89.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-89.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-89.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-89.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-54.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-54.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-54.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-54.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-54.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-54.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-55.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-55.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-55.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-55.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-55.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-55.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-55.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-55.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-55.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-92.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-92.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-92.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-92.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-56.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-56.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-56.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-56.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-56.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-56.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-57.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-57.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-57.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-57.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-57.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-57.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-57.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-57.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-57.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-95.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-95.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-95.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-95.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-96.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-96.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-96.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-96.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-58.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-58.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-58.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-58.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-58.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-58.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-59.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-59.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-59.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-59.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-59.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-59.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-59.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-59.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-59.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-99.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-99.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-99.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-99.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-60.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-60.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-60.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-60.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-60.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-60.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-61.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-61.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-61.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-61.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-61.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-61.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-61.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-61.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-61.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-102.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-102.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-102.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-102.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-62.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-62.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-62.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-62.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-62.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-62.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-63.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-63.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-63.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-63.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-63.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-63.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-63.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-63.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-63.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-105.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-105.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-105.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-105.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-106.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-106.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-106.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-106.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-64.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-64.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-64.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-64.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-64.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-64.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-65.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-65.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-65.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-65.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-65.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-65.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-65.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-65.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-65.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-109.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-109.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-109.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-109.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-66.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-66.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-66.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-66.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-66.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-66.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-67.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-67.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-67.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-67.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-67.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-67.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-67.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-67.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-67.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-112.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-112.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-112.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-112.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-68.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-68.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-68.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-68.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-68.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-68.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-69.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-69.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-69.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-69.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-69.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-69.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-69.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-69.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-69.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-115.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-115.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-115.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-115.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-116.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-116.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-116.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-116.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-70.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-70.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-70.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-70.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-70.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-70.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-71.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-71.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-71.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-71.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-71.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-71.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-71.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-71.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-71.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-119.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-119.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-119.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-119.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-72.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-72.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-72.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-72.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-72.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-72.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-73.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-73.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-73.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-73.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-73.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-73.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-73.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-73.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-73.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-74.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-74.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-74.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-74.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-74.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-123.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-123.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-123.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-123.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-75.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-75.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-75.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-75.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-75.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-75.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-75.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-75.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-75.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-125.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-125.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-125.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-125.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-76.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-76.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-76.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-76.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-76.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-76.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-77.axis
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-77.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-77.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-77.moving_mean
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-77.moving_variance
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-77.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-77.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-77.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer_with_weights-77.keras_api
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-128.variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-128.trainable_variables
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-128.regularization_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).layer-128.keras_api
# ...
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-77.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-77.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-78.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-78.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-79.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-79.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-80.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-80.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-81.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-81.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-82.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-82.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-26.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-27.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-27.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-28.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-28.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-29.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-29.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-30.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-30.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-31.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-31.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-32.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-32.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-33.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-33.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-34.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-34.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-35.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-35.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-36.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-36.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-37.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-37.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-38.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-38.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-39.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-39.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-40.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-40.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-41.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-41.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-42.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-42.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-43.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-43.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-44.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-44.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-45.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-45.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-46.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-46.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-47.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-47.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-48.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-48.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-49.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-49.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-50.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-50.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-51.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-51.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-52.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-52.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-53.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-53.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-54.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-54.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-55.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-55.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-56.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-56.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-57.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-57.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-58.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-58.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-59.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-59.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-60.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-60.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-61.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-61.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-62.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-62.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-63.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-63.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-64.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-64.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-65.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-65.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-66.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-66.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-67.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-67.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-68.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-68.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-69.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-69.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-70.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-70.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-71.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-71.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-72.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-72.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-73.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-73.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-74.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-75.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-75.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-76.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-76.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-77.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-77.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-78.depthwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-78.pointwise_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-79.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-79.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-80.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-80.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-81.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-81.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-82.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-82.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.

# %%
loss, acc = model_final.evaluate_generator(validation_generator, 400)
print('Restored model, accuracy: {:5.2f}%'.format(100*acc))
# Out:
# Restored model, accuracy: 76.49%

# %%
prob=model_final.predict(validation_generator)
import numpy as np
ypred=np.argmax(prob,axis=1)

y_true=validation_generator.classes

tf.math.confusion_matrix(y_true,ypred)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-ca4d9e1ce104> in <module>()
# ----> 1 prob=model_final.predict(validation_generator)
#       2 import numpy as np
#       3 ypred=np.argmax(prob,axis=1)
#       4
#       5 y_true=validation_generator.classes
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      86       raise ValueError('{} is not supported in multi-worker mode.'.format(
#      87           method.__name__))
# ---> 88     return method(self, *args, **kwargs)
#      89
#      90   return tf_decorator.make_decorator(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1269           for step in data_handler.steps():
#    1270             callbacks.on_predict_batch_begin(step)
# -> 1271             tmp_batch_outputs = predict_function(iterator)
#    1272             # Catch OutOfRangeError for Datasets of unknown size.
#    1273             # This blocks until the batch has finished executing.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     616       # In this case we have not created variables on the first call. So we can
#     617       # run the first trace but we should fail if variables are created.
# --> 618       results = self._stateful_fn(*args, **kwds)
#     619       if self._created_variables:
#     620         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# #grupo 1
#
# fried_rice/    gnocchi/      grilled_cheese_sandwich/
# garlic_bread/  greek_salad/  grilled_salmon/

# %%
ls grupo1
# Out:
# fried_rice/    gnocchi/      grilled_cheese_sandwich/
# garlic_bread/  greek_salad/  grilled_salmon/

# %%
train_data_dir='grupo1'

# %%
train_datagen = ImageDataGenerator(rescale=1/255.,
    horizontal_flip=False,
    validation_split=0.2) # set validation split

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training', seed=seed) # set as training data

validation_generator = train_datagen.flow_from_directory(
    train_data_dir, # same directory as training data
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation', seed=seed) # set as validation data
# Out:
# Found 4825 images belonging to 6 classes.
# Found 1206 images belonging to 6 classes.

# %%
#model_final.compile(loss='categorical_crossentropy', optimizer=optimizers.Adam(lr=0.00008, beta_1=0.9, beta_2=0.97, epsilon=1e-7))
#batch_size=128
from keras import applications
model =applications.Xception(weights = "imagenet", include_top=False, input_shape = (112,112,3))
for layer in model.layers[:100]:
    layer.trainable = False
regparameter=0.001
#Adding custom Layers 

x = model.output
x = Flatten()(x)
x = Dense(256, activation="relu",kernel_regularizer=tf.keras.regularizers.l1_l2(l1=regparameter,l2=regparameter))(x)
x = Dropout(0.5)(x)
x = Dense(4096, activation="relu")(x)
predictions = Dense(6, activation="softmax")(x)

# creating the final model 
model_final = Model(input = model.input, output = predictions)

# compile the model 
model_final.compile(loss = "categorical_crossentropy", optimizer = 'adam', metrics=["accuracy"])
model_final.summary()
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.4/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 3s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 112, 112, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 55, 55, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 55, 55, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 55, 55, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 53, 53, 64)   18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 53, 53, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 53, 53, 64)   0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 53, 53, 128)  8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 53, 53, 128)  512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 53, 53, 128)  0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 53, 53, 128)  17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 53, 53, 128)  512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 27, 27, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 27, 27, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 27, 27, 128)  512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 27, 27, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 27, 27, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 27, 27, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 27, 27, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 27, 27, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 27, 27, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 27, 27, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 256)  32768       add_1[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 14, 14, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 14, 14, 256)  1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 14, 14, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 14, 14, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 14, 14, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 14, 14, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 14, 14, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 14, 14, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 14, 14, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 7, 7, 728)    186368      add_2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 7, 7, 728)    0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 7, 7, 728)    2912        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 7, 7, 728)    0           block4_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 7, 7, 728)    0           add_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 7, 7, 728)    536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 7, 7, 728)    2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 7, 7, 728)    0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 7, 7, 728)    536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 7, 7, 728)    2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 7, 7, 728)    0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 7, 7, 728)    536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 7, 7, 728)    2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 7, 7, 728)    0           block5_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 7, 7, 728)    0           add_4[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 7, 7, 728)    536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 7, 7, 728)    2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 7, 7, 728)    0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 7, 7, 728)    536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 7, 7, 728)    2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 7, 7, 728)    0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 7, 7, 728)    536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 7, 7, 728)    2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 7, 7, 728)    0           block6_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 7, 7, 728)    0           add_5[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 7, 7, 728)    536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 7, 7, 728)    2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 7, 7, 728)    0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 7, 7, 728)    536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 7, 7, 728)    2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 7, 7, 728)    0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 7, 7, 728)    536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 7, 7, 728)    2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 7, 7, 728)    0           block7_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 7, 7, 728)    0           add_6[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 7, 7, 728)    536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 7, 7, 728)    2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 7, 7, 728)    0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 7, 7, 728)    536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 7, 7, 728)    2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 7, 7, 728)    0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 7, 7, 728)    536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 7, 7, 728)    2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, 7, 728)    0           block8_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 7, 7, 728)    0           add_7[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 7, 7, 728)    536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 7, 7, 728)    2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 7, 7, 728)    0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 7, 7, 728)    536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 7, 7, 728)    2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 7, 7, 728)    0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 7, 7, 728)    536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 7, 7, 728)    2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 7, 7, 728)    0           block9_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 7, 7, 728)    0           add_8[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 7, 7, 728)    536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 7, 7, 728)    2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 7, 7, 728)    0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 7, 7, 728)    536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 7, 7, 728)    2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 7, 7, 728)    0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 7, 7, 728)    536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 7, 7, 728)    2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 7, 7, 728)    0           block10_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 7, 7, 728)    0           add_9[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 7, 7, 728)    536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 7, 7, 728)    2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 7, 7, 728)    0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 7, 7, 728)    536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 7, 7, 728)    2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 7, 7, 728)    0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 7, 7, 728)    536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 7, 7, 728)    2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 7, 7, 728)    0           block11_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 7, 7, 728)    0           add_10[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 7, 7, 728)    536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 7, 7, 728)    2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 7, 7, 728)    0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 7, 7, 728)    536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 7, 7, 728)    2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 7, 7, 728)    0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 7, 7, 728)    536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 7, 7, 728)    2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 7, 7, 728)    0           block12_sepconv3_bn[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 7, 7, 728)    0           add_11[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 7, 7, 728)    536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 7, 7, 728)    2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 7, 7, 728)    0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 7, 7, 1024)   752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 7, 7, 1024)   4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 1024)   745472      add_11[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 4, 4, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 4, 4, 1024)   4096        conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 4, 4, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 4, 4, 1536)   1582080     add_12[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 4, 4, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 4, 4, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 4, 4, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 4, 4, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 4, 4, 2048)   0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 32768)        0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          8388864     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 4096)         1052672     dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 6)            24582       dense_2[0][0]
# ==================================================================================================
# Total params: 30,327,598
# Trainable params: 18,944,462
# Non-trainable params: 11,383,136
# __________________________________________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   app.launch_new_instance()

# %%
chkpt = ModelCheckpoint(filepath='grupo1_6class_reg_001.hdf5', save_best_only=True, save_weights_only=True)

# %%
model_final.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // batch_size,
    epochs = 20,callbacks=[chkpt])
# Out:
# Epoch 1/20
# 301/301 [==============================] - 3841s 13s/step - loss: 4.5706 - accuracy: 0.5176 - val_loss: 1.8842 - val_accuracy: 0.6358
# Epoch 2/20
# 301/301 [==============================] - 681s 2s/step - loss: 2.3585 - accuracy: 0.6675 - val_loss: 2.4582 - val_accuracy: 0.5891
# Epoch 3/20
# 301/301 [==============================] - 680s 2s/step - loss: 2.0176 - accuracy: 0.7440 - val_loss: 2.2309 - val_accuracy: 0.6639
# Epoch 4/20
# 301/301 [==============================] - 679s 2s/step - loss: 1.8150 - accuracy: 0.7898 - val_loss: 1.9290 - val_accuracy: 0.6353
# Epoch 5/20
# 301/301 [==============================] - 687s 2s/step - loss: 1.9702 - accuracy: 0.8201 - val_loss: 2.0777 - val_accuracy: 0.6160
# Epoch 6/20
# 301/301 [==============================] - 655s 2s/step - loss: 1.5468 - accuracy: 0.8659 - val_loss: 3.0738 - val_accuracy: 0.6387
# Epoch 7/20
# 301/301 [==============================] - 671s 2s/step - loss: 1.4685 - accuracy: 0.8896 - val_loss: 2.7008 - val_accuracy: 0.6790
# Epoch 8/20
# 301/301 [==============================] - 670s 2s/step - loss: 1.3858 - accuracy: 0.9137 - val_loss: 2.4649 - val_accuracy: 0.7000
# Epoch 9/20
# 301/301 [==============================] - 661s 2s/step - loss: 1.3732 - accuracy: 0.9289 - val_loss: 3.3345 - val_accuracy: 0.6387
# Epoch 10/20
# 301/301 [==============================] - 660s 2s/step - loss: 1.2960 - accuracy: 0.9384 - val_loss: 1.7387 - val_accuracy: 0.6731
# Epoch 11/20
# 301/301 [==============================] - 653s 2s/step - loss: 1.4125 - accuracy: 0.9320 - val_loss: 2.7192 - val_accuracy: 0.6807
# Epoch 12/20
# 301/301 [==============================] - 660s 2s/step - loss: 1.3405 - accuracy: 0.9474 - val_loss: 1.8697 - val_accuracy: 0.6655
# Epoch 13/20
# 301/301 [==============================] - 672s 2s/step - loss: 1.2910 - accuracy: 0.9561 - val_loss: 1.4809 - val_accuracy: 0.7025
# Epoch 14/20
# 301/301 [==============================] - 654s 2s/step - loss: 1.2949 - accuracy: 0.9599 - val_loss: 3.1646 - val_accuracy: 0.6664
# Epoch 15/20
# 301/301 [==============================] - 655s 2s/step - loss: 1.2942 - accuracy: 0.9549 - val_loss: 3.1941 - val_accuracy: 0.6504
# Epoch 16/20
# 301/301 [==============================] - 646s 2s/step - loss: 1.2693 - accuracy: 0.9610 - val_loss: 2.3672 - val_accuracy: 0.6513
# Epoch 17/20
# 301/301 [==============================] - 644s 2s/step - loss: 1.4559 - accuracy: 0.9548 - val_loss: 3.6609 - val_accuracy: 0.6042
# Epoch 18/20
# 301/301 [==============================] - 662s 2s/step - loss: 1.2871 - accuracy: 0.9646 - val_loss: 3.0243 - val_accuracy: 0.6462
# Epoch 19/20
# 301/301 [==============================] - 646s 2s/step - loss: 1.2356 - accuracy: 0.9748 - val_loss: 3.1575 - val_accuracy: 0.5832
# Epoch 20/20
# 301/301 [==============================] - 640s 2s/step - loss: 1.3037 - accuracy: 0.9719 - val_loss: 2.0297 - val_accuracy: 0.7210

# %%
prob=model_final.predict(validation_generator)
import numpy as np
ypred=np.argmax(prob,axis=1)

y_true=validation_generator.classes

tf.math.confusion_matrix(y_true,ypred)

# %% [markdown]
# #Grupo 2

# %%
ls grupo2
# Out:
# gyoza/  hot_and_sour_soup/  huevos_rancheros/  hummus/  ice_cream/  lasagna/

# %%
train_data_dir='grupo2'

# %%
train_datagen = ImageDataGenerator(rescale=1/255.,
    horizontal_flip=False,
    validation_split=0.2) # set validation split

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training', seed=seed) # set as training data

validation_generator = train_datagen.flow_from_directory(
    train_data_dir, # same directory as training data
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation', seed=seed) # set as validation data
# Out:
# Found 4831 images belonging to 6 classes.
# Found 1207 images belonging to 6 classes.

# %%
#model_final.compile(loss='categorical_crossentropy', optimizer=optimizers.Adam(lr=0.00008, beta_1=0.9, beta_2=0.97, epsilon=1e-7))
#batch_size=128
from keras import applications
model =applications.Xception(weights = "imagenet", include_top=False, input_shape = (112,112,3))
for layer in model.layers[:100]:
    layer.trainable = False
regparameter=0.001
#Adding custom Layers 

x = model.output
x = Flatten()(x)
x = Dense(256, activation="relu",kernel_regularizer=tf.keras.regularizers.l1_l2(l1=regparameter,l2=regparameter))(x)
x = Dropout(0.5)(x)
x = Dense(4096, activation="relu")(x)
predictions = Dense(6, activation="softmax")(x)

# creating the final model 
model_final = Model(input = model.input, output = predictions)

# compile the model 
model_final.compile(loss = "categorical_crossentropy", optimizer = 'adam', metrics=["accuracy"])
model_final.summary()
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.4/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 112, 112, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 55, 55, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 55, 55, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 55, 55, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 53, 53, 64)   18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 53, 53, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 53, 53, 64)   0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 53, 53, 128)  8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 53, 53, 128)  512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 53, 53, 128)  0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 53, 53, 128)  17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 53, 53, 128)  512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 27, 27, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 27, 27, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 27, 27, 128)  512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 27, 27, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 27, 27, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 27, 27, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 27, 27, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 27, 27, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 27, 27, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 27, 27, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 256)  32768       add_1[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 14, 14, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 14, 14, 256)  1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 14, 14, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 14, 14, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 14, 14, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 14, 14, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 14, 14, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 14, 14, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 14, 14, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 7, 7, 728)    186368      add_2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 7, 7, 728)    0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 7, 7, 728)    2912        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 7, 7, 728)    0           block4_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 7, 7, 728)    0           add_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 7, 7, 728)    536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 7, 7, 728)    2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 7, 7, 728)    0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 7, 7, 728)    536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 7, 7, 728)    2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 7, 7, 728)    0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 7, 7, 728)    536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 7, 7, 728)    2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 7, 7, 728)    0           block5_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 7, 7, 728)    0           add_4[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 7, 7, 728)    536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 7, 7, 728)    2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 7, 7, 728)    0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 7, 7, 728)    536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 7, 7, 728)    2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 7, 7, 728)    0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 7, 7, 728)    536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 7, 7, 728)    2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 7, 7, 728)    0           block6_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 7, 7, 728)    0           add_5[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 7, 7, 728)    536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 7, 7, 728)    2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 7, 7, 728)    0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 7, 7, 728)    536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 7, 7, 728)    2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 7, 7, 728)    0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 7, 7, 728)    536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 7, 7, 728)    2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 7, 7, 728)    0           block7_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 7, 7, 728)    0           add_6[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 7, 7, 728)    536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 7, 7, 728)    2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 7, 7, 728)    0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 7, 7, 728)    536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 7, 7, 728)    2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 7, 7, 728)    0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 7, 7, 728)    536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 7, 7, 728)    2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, 7, 728)    0           block8_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 7, 7, 728)    0           add_7[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 7, 7, 728)    536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 7, 7, 728)    2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 7, 7, 728)    0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 7, 7, 728)    536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 7, 7, 728)    2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 7, 7, 728)    0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 7, 7, 728)    536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 7, 7, 728)    2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 7, 7, 728)    0           block9_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 7, 7, 728)    0           add_8[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 7, 7, 728)    536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 7, 7, 728)    2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 7, 7, 728)    0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 7, 7, 728)    536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 7, 7, 728)    2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 7, 7, 728)    0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 7, 7, 728)    536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 7, 7, 728)    2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 7, 7, 728)    0           block10_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 7, 7, 728)    0           add_9[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 7, 7, 728)    536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 7, 7, 728)    2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 7, 7, 728)    0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 7, 7, 728)    536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 7, 7, 728)    2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 7, 7, 728)    0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 7, 7, 728)    536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 7, 7, 728)    2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 7, 7, 728)    0           block11_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 7, 7, 728)    0           add_10[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 7, 7, 728)    536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 7, 7, 728)    2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 7, 7, 728)    0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 7, 7, 728)    536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 7, 7, 728)    2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 7, 7, 728)    0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 7, 7, 728)    536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 7, 7, 728)    2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 7, 7, 728)    0           block12_sepconv3_bn[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 7, 7, 728)    0           add_11[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 7, 7, 728)    536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 7, 7, 728)    2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 7, 7, 728)    0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 7, 7, 1024)   752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 7, 7, 1024)   4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 1024)   745472      add_11[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 4, 4, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 4, 4, 1024)   4096        conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 4, 4, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 4, 4, 1536)   1582080     add_12[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 4, 4, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 4, 4, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 4, 4, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 4, 4, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 4, 4, 2048)   0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 32768)        0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          8388864     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 4096)         1052672     dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 6)            24582       dense_2[0][0]
# ==================================================================================================
# Total params: 30,327,598
# Trainable params: 18,944,462
# Non-trainable params: 11,383,136
# __________________________________________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   app.launch_new_instance()

# %%
chkpt = ModelCheckpoint(filepath='grupo2_6class_reg_001.hdf5', save_best_only=True, save_weights_only=True)

# %%
model_final.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // batch_size,
    epochs = 20,callbacks=[chkpt])
# Out:
# Epoch 1/20
# 301/301 [==============================] - 2412s 8s/step - loss: 5.0059 - accuracy: 0.4218 - val_loss: 2.9697 - val_accuracy: 0.5242
# Epoch 2/20
# 301/301 [==============================] - 695s 2s/step - loss: 2.3012 - accuracy: 0.6359 - val_loss: 2.5430 - val_accuracy: 0.6700
# Epoch 3/20
# 301/301 [==============================] - 697s 2s/step - loss: 2.1449 - accuracy: 0.7364 - val_loss: 2.0843 - val_accuracy: 0.7397
# Epoch 4/20
# 301/301 [==============================] - 694s 2s/step - loss: 2.2560 - accuracy: 0.7909 - val_loss: 1.8360 - val_accuracy: 0.7615
# Epoch 5/20
# 301/301 [==============================] - 693s 2s/step - loss: 1.7852 - accuracy: 0.8403 - val_loss: 1.8142 - val_accuracy: 0.6885
# Epoch 6/20
# 301/301 [==============================] - 695s 2s/step - loss: 2.0627 - accuracy: 0.8498 - val_loss: 2.3617 - val_accuracy: 0.6969
# Epoch 7/20
# 301/301 [==============================] - 703s 2s/step - loss: 1.6824 - accuracy: 0.8864 - val_loss: 1.9032 - val_accuracy: 0.7422
# Epoch 8/20
# 301/301 [==============================] - 691s 2s/step - loss: 1.5135 - accuracy: 0.9125 - val_loss: 1.5973 - val_accuracy: 0.6683
# Epoch 9/20
# 301/301 [==============================] - 696s 2s/step - loss: 1.5122 - accuracy: 0.9211 - val_loss: 2.0649 - val_accuracy: 0.6406
# Epoch 10/20
# 301/301 [==============================] - 695s 2s/step - loss: 1.3157 - accuracy: 0.9371 - val_loss: 2.6894 - val_accuracy: 0.7540
# Epoch 11/20
# 301/301 [==============================] - 696s 2s/step - loss: 1.4914 - accuracy: 0.9323 - val_loss: 1.9874 - val_accuracy: 0.7456
# Epoch 12/20
# 301/301 [==============================] - 694s 2s/step - loss: 1.3322 - accuracy: 0.9543 - val_loss: 1.5899 - val_accuracy: 0.7196
# Epoch 13/20
# 301/301 [==============================] - 704s 2s/step - loss: 1.4067 - accuracy: 0.9445 - val_loss: 2.1677 - val_accuracy: 0.7086
# Epoch 14/20
# 301/301 [==============================] - 700s 2s/step - loss: 1.2063 - accuracy: 0.9620 - val_loss: 1.4330 - val_accuracy: 0.7448
# Epoch 15/20
# 301/301 [==============================] - 705s 2s/step - loss: 1.3167 - accuracy: 0.9616 - val_loss: 2.1378 - val_accuracy: 0.7221
# Epoch 16/20
# 301/301 [==============================] - 699s 2s/step - loss: 1.2567 - accuracy: 0.9620 - val_loss: 2.7670 - val_accuracy: 0.7170
# Epoch 17/20
# 301/301 [==============================] - 707s 2s/step - loss: 1.2716 - accuracy: 0.9630 - val_loss: 2.4776 - val_accuracy: 0.7238
# Epoch 18/20
# 301/301 [==============================] - 703s 2s/step - loss: 1.1198 - accuracy: 0.9722 - val_loss: 1.3462 - val_accuracy: 0.7288
# Epoch 19/20
# 301/301 [==============================] - 706s 2s/step - loss: 1.2769 - accuracy: 0.9641 - val_loss: 2.0269 - val_accuracy: 0.6944
# Epoch 20/20
# 301/301 [==============================] - 704s 2s/step - loss: 1.2064 - accuracy: 0.9755 - val_loss: 1.8163 - val_accuracy: 0.6113

# %%
model_final.load_weights('grupo2_6class_reg_001.hdf5')

# %%
loss,acc = model_final.evaluate(validation_generator, verbose=1)
# Out:
# 76/76 [==============================] - 542s 7s/step

# %%
print(loss,acc)
# Out:
# 2.5716795921325684 0.7257663607597351

# %%
prob=model_final.predict(validation_generator, verbose=1))
import numpy as np
ypred=np.argmax(prob,axis=1)

y_true=validation_generator.classes

tf.math.confusion_matrix(y_true,ypred)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-ca4d9e1ce104> in <module>()
# ----> 1 prob=model_final.predict(validation_generator)
#       2 import numpy as np
#       3 ypred=np.argmax(prob,axis=1)
#       4
#       5 y_true=validation_generator.classes
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1431                 max_queue_size=max_queue_size,
#    1432                 workers=workers,
# -> 1433                 use_multiprocessing=use_multiprocessing)
#    1434
#    1435         if x is None and steps is None:
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in predict_generator(self, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#    1844             workers=workers,
#    1845             use_multiprocessing=use_multiprocessing,
# -> 1846             verbose=verbose)
#    1847
#    1848
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in predict_generator(model, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#     489
#     490         while steps_done < steps:
# --> 491             generator_output = next(output_generator)
#     492             if isinstance(generator_output, tuple):
#     493                 # Compatibility with the generators
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py in get(self)
#     608                 try:
#     609                     future = self.queue.get(block=True)
# --> 610                     inputs = future.get(timeout=30)
#     611                 except mp.TimeoutError:
#     612                     idx = future.idx
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /usr/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
model_final.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // batch_size,
    epochs = 50,callbacks=[chkpt])

# %% [markdown]
# #Grupo 3

# %%
train_data_dir='grupo3'

# %%
train_datagen = ImageDataGenerator(rescale=1/255.,
    horizontal_flip=False,
    validation_split=0.2) # set validation split

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training', seed=seed) # set as training data

validation_generator = train_datagen.flow_from_directory(
    train_data_dir, # same directory as training data
    target_size=IMG_SIZE,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation', seed=seed) # set as validation data
# Out:
# Found 4814 images belonging to 6 classes.
# Found 1203 images belonging to 6 classes.

# %%
#model_final.compile(loss='categorical_crossentropy', optimizer=optimizers.Adam(lr=0.00008, beta_1=0.9, beta_2=0.97, epsilon=1e-7))
#batch_size=128
from keras import applications
model =applications.Xception(weights = "imagenet", include_top=False, input_shape = (112,112,3))
for layer in model.layers[:100]:
    layer.trainable = False
regparameter=0.001
#Adding custom Layers 

x = model.output
x = Flatten()(x)
x = Dense(256, activation="relu",kernel_regularizer=tf.keras.regularizers.l1_l2(l1=regparameter,l2=regparameter))(x)
x = Dropout(0.5)(x)
x = Dense(4096, activation="relu")(x)
predictions = Dense(6, activation="softmax")(x)

# creating the final model 
model_final = Model(input = model.input, output = predictions)

# compile the model 
model_final.compile(loss = "categorical_crossentropy", optimizer = 'adam', metrics=["accuracy"])
model_final.summary()
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.4/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 112, 112, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 55, 55, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 55, 55, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 55, 55, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 53, 53, 64)   18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 53, 53, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 53, 53, 64)   0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 53, 53, 128)  8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 53, 53, 128)  512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 53, 53, 128)  0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 53, 53, 128)  17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 53, 53, 128)  512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 27, 27, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 27, 27, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 27, 27, 128)  512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 27, 27, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 27, 27, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 27, 27, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 27, 27, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 27, 27, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 27, 27, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 27, 27, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 256)  32768       add_1[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 14, 14, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 14, 14, 256)  1024        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 14, 14, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 14, 14, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 14, 14, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 14, 14, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 14, 14, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 14, 14, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 14, 14, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 7, 7, 728)    186368      add_2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 7, 7, 728)    0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 7, 7, 728)    2912        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 7, 7, 728)    0           block4_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 7, 7, 728)    0           add_3[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 7, 7, 728)    536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 7, 7, 728)    2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 7, 7, 728)    0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 7, 7, 728)    536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 7, 7, 728)    2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 7, 7, 728)    0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 7, 7, 728)    536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 7, 7, 728)    2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 7, 7, 728)    0           block5_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 7, 7, 728)    0           add_4[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 7, 7, 728)    536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 7, 7, 728)    2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 7, 7, 728)    0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 7, 7, 728)    536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 7, 7, 728)    2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 7, 7, 728)    0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 7, 7, 728)    536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 7, 7, 728)    2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 7, 7, 728)    0           block6_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 7, 7, 728)    0           add_5[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 7, 7, 728)    536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 7, 7, 728)    2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 7, 7, 728)    0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 7, 7, 728)    536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 7, 7, 728)    2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 7, 7, 728)    0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 7, 7, 728)    536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 7, 7, 728)    2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 7, 7, 728)    0           block7_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 7, 7, 728)    0           add_6[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 7, 7, 728)    536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 7, 7, 728)    2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 7, 7, 728)    0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 7, 7, 728)    536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 7, 7, 728)    2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 7, 7, 728)    0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 7, 7, 728)    536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 7, 7, 728)    2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 7, 7, 728)    0           block8_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 7, 7, 728)    0           add_7[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 7, 7, 728)    536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 7, 7, 728)    2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 7, 7, 728)    0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 7, 7, 728)    536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 7, 7, 728)    2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 7, 7, 728)    0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 7, 7, 728)    536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 7, 7, 728)    2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 7, 7, 728)    0           block9_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 7, 7, 728)    0           add_8[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 7, 7, 728)    536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 7, 7, 728)    2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 7, 7, 728)    0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 7, 7, 728)    536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 7, 7, 728)    2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 7, 7, 728)    0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 7, 7, 728)    536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 7, 7, 728)    2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 7, 7, 728)    0           block10_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 7, 7, 728)    0           add_9[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 7, 7, 728)    536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 7, 7, 728)    2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 7, 7, 728)    0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 7, 7, 728)    536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 7, 7, 728)    2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 7, 7, 728)    0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 7, 7, 728)    536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 7, 7, 728)    2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 7, 7, 728)    0           block11_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 7, 7, 728)    0           add_10[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 7, 7, 728)    536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 7, 7, 728)    2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 7, 7, 728)    0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 7, 7, 728)    536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 7, 7, 728)    2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 7, 7, 728)    0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 7, 7, 728)    536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 7, 7, 728)    2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 7, 7, 728)    0           block12_sepconv3_bn[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 7, 7, 728)    0           add_11[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 7, 7, 728)    536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 7, 7, 728)    2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 7, 7, 728)    0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 7, 7, 1024)   752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 7, 7, 1024)   4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 1024)   745472      add_11[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 4, 4, 1024)   0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 4, 4, 1024)   4096        conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 4, 4, 1024)   0           block13_pool[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 4, 4, 1536)   1582080     add_12[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 4, 4, 1536)   6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 4, 4, 1536)   0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 4, 4, 2048)   3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 4, 4, 2048)   8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 4, 4, 2048)   0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 32768)        0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          8388864     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 4096)         1052672     dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 6)            24582       dense_2[0][0]
# ==================================================================================================
# Total params: 30,327,598
# Trainable params: 18,944,462
# Non-trainable params: 11,383,136
# __________________________________________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   app.launch_new_instance()

# %%
chkpt = ModelCheckpoint(filepath='grupo3_6class_reg_001.hdf5', save_best_only=True, save_weights_only=True)

# %%
model_final.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // batch_size,
    epochs = 20,callbacks=[chkpt])
# Out:
# Epoch 1/20
# 300/300 [==============================] - 2501s 8s/step - loss: 1.6654 - accuracy: 0.9239 - val_loss: 5.4066 - val_accuracy: 0.7433
# Epoch 2/20
# 300/300 [==============================] - 710s 2s/step - loss: 1.5106 - accuracy: 0.9456 - val_loss: 3.2087 - val_accuracy: 0.7068
# Epoch 3/20
# 300/300 [==============================] - 716s 2s/step - loss: 1.7677 - accuracy: 0.9387 - val_loss: 3.1078 - val_accuracy: 0.7372
# Epoch 4/20
# 300/300 [==============================] - 705s 2s/step - loss: 1.3518 - accuracy: 0.9608 - val_loss: 2.1362 - val_accuracy: 0.7801
# Epoch 5/20
# 300/300 [==============================] - 713s 2s/step - loss: 1.3337 - accuracy: 0.9692 - val_loss: 3.2622 - val_accuracy: 0.7557
# Epoch 6/20
# 300/300 [==============================] - 704s 2s/step - loss: 1.8831 - accuracy: 0.9521 - val_loss: 3.2780 - val_accuracy: 0.6849
# Epoch 7/20
# 300/300 [==============================] - 704s 2s/step - loss: 1.3096 - accuracy: 0.9708 - val_loss: 2.1872 - val_accuracy: 0.7953
# Epoch 8/20
# 300/300 [==============================] - 708s 2s/step - loss: 1.2096 - accuracy: 0.9731 - val_loss: 2.6831 - val_accuracy: 0.7776
# Epoch 9/20
# 300/300 [==============================] - 703s 2s/step - loss: 1.2615 - accuracy: 0.9742 - val_loss: 1.9324 - val_accuracy: 0.8374
# Epoch 10/20
# 300/300 [==============================] - 708s 2s/step - loss: 1.2588 - accuracy: 0.9754 - val_loss: 2.7230 - val_accuracy: 0.8054
# Epoch 11/20
# 300/300 [==============================] - 714s 2s/step - loss: 1.4030 - accuracy: 0.9767 - val_loss: 1.8184 - val_accuracy: 0.7869
# Epoch 12/20
# 300/300 [==============================] - 740s 2s/step - loss: 1.3367 - accuracy: 0.9689 - val_loss: 1.7481 - val_accuracy: 0.7633
# Epoch 13/20
# 300/300 [==============================] - 747s 2s/step - loss: 1.1963 - accuracy: 0.9771 - val_loss: 2.7180 - val_accuracy: 0.7658
# Epoch 14/20
# 300/300 [==============================] - 735s 2s/step - loss: 1.1670 - accuracy: 0.9840 - val_loss: 1.9047 - val_accuracy: 0.7953
# Epoch 15/20
# 300/300 [==============================] - 726s 2s/step - loss: 1.2121 - accuracy: 0.9815 - val_loss: 2.1022 - val_accuracy: 0.8003
# Epoch 16/20
# 300/300 [==============================] - 742s 2s/step - loss: 1.2135 - accuracy: 0.9848 - val_loss: 3.3394 - val_accuracy: 0.7599
# Epoch 17/20
# 300/300 [==============================] - 732s 2s/step - loss: 1.3896 - accuracy: 0.9708 - val_loss: 2.8277 - val_accuracy: 0.7245
# Epoch 18/20
# 300/300 [==============================] - 732s 2s/step - loss: 1.1875 - accuracy: 0.9817 - val_loss: 2.9170 - val_accuracy: 0.7489
# Epoch 19/20
# 300/300 [==============================] - 740s 2s/step - loss: 1.4198 - accuracy: 0.9802 - val_loss: 3.1257 - val_accuracy: 0.7380
# Epoch 20/20
# 300/300 [==============================] - 732s 2s/step - loss: 1.4432 - accuracy: 0.9787 - val_loss: 2.5983 - val_accuracy: 0.7161

# %%
model_final.load_weights('grupo3_6class_reg_001.hdf5')

# %%
loss,acc = model_final.evaluate(validation_generator, verbose=1)
# Out:
# 76/76 [==============================] - 82s 1s/step

# %%
print(loss,acc)
# Out:
# 1.032043695449829 0.6824604868888855
